# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cst_ckpt = pd.read_csv('1h-ckpt-cielo.csv', 
                       names=["Bandwidth", "MTBF", "Interference", "WORK", "IO", "CKPT", "WASTED", "TOTAL", "seed", "Convergence"])
daly_ckpt = pd.read_csv('daly-ckpt-cielo.csv', 
                        names=["Bandwidth", "MTBF", "Interference", "WORK", "IO", "CKPT", "WASTED", "TOTAL", "seed", "Convergence"])

# %%
bw=1.6e11
A=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="Simple"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:red',
         label="No Interference Management Strategy, 1h Checkpoint Interval")
A=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="Simple"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:blue',
         label="No Interference Management Strategy, Daly Checkpoint Interval")
A=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="BLOCKING_FCFS"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:purple',
         label="FCFS Interference Management Strategy, 1h Checkpoint Interval")
A=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="BLOCKING_FCFS"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:green',
         label="FCFS Interference Management Strategy, Daly Checkpoint Interval")
lgd = plt.legend(bbox_to_anchor=(0., 1.05, 1., .102), loc=3, mode="expand", borderaxespad=0.)
plt.title('Bandwidth: ' + str(bw/1e9) + 'GB/s, APEX Workflow use case')
plt.xlabel('Node MTBF (Years)')
plt.ylabel('Average Checkpoint Slowdown due to Interference')
plt.ylim(ymin=1.0, ymax=4.0)
plt.savefig('ckpt-slowdown-160Gbs.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
bw=8e10
A=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="Simple"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:red',
         label="No Interference Management Strategy, 1h Checkpoint Interval")
A=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="Simple"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:blue',
         label="No Interference Management Strategy, Daly Checkpoint Interval")
A=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="BLOCKING_FCFS"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:purple',
         label="FCFS Interference Management Strategy, 1h Checkpoint Interval")
A=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="BLOCKING_FCFS"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:green',
         label="FCFS Interference Management Strategy, Daly Checkpoint Interval")
lgd = plt.legend(bbox_to_anchor=(0., 1.05, 1., .102), loc=3, mode="expand", borderaxespad=0.)
plt.title('Bandwidth: ' + str(bw/1e9) + 'GB/s, APEX Workflow use case')
plt.xlabel('Node MTBF (Years)')
plt.ylabel('Average Checkpoint Slowdown due to Interference')
plt.ylim(ymin=1.0, ymax=4.0)
plt.savefig('ckpt-slowdown-80Gbs.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
bw=4e10
A=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="Simple"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
R.drop(3600,inplace=True)
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:red',
         label="No Interference Management Strategy, 1h Checkpoint Interval")
A=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="Simple"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
R.drop(3600,inplace=True)
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:blue',
         label="No Interference Management Strategy, Daly Checkpoint Interval")
A=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="BLOCKING_FCFS"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=cst_ckpt[((cst_ckpt.Bandwidth==bw) & (cst_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
R.drop(3600,inplace=True)
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:purple',
         label="FCFS Interference Management Strategy, 1h Checkpoint Interval")
A=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="BLOCKING_FCFS"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
B=daly_ckpt[((daly_ckpt.Bandwidth==bw) & (daly_ckpt.Interference=="No"))].groupby('MTBF').mean().reset_index().set_index('MTBF')
R=A/B
R.drop(3600,inplace=True)
plt.plot(R.index.values*18860/3600/24/365, R['CKPT'], 
         'tab:green',
         label="FCFS Interference Management Strategy, Daly Checkpoint Interval")
lgd = plt.legend(bbox_to_anchor=(0., 1.05, 1., .102), loc=3, mode="expand", borderaxespad=0.)
plt.title('Bandwidth: ' + str(bw/1e9) + 'GB/s, APEX Workflow use case')
plt.xlabel('Node MTBF (Years)')
plt.ylabel('Average Checkpoint Slowdown due to Interference')
plt.ylim(ymin=1.0, ymax=4.0)
plt.savefig('ckpt-slowdown-40Gbs.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')
